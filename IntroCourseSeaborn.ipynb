# %% [markdown]
# <a href="https://colab.research.google.com/github/feliperodighero/Seaborn-Course/blob/main/IntroCourseSeaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [10, 20, 30 , 40]
y = [0, 15, 10, 25]

# %%
plt.plot(x, y)

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
sns.set()

# %%
plt.plot(x, y)

# %%
sns.set_style('white')

# %%
plt.plot(x, y)
