# %% [markdown]
# <a href="https://colab.research.google.com/github/feliperodighero/Seaborn-Course/blob/main/KDE_Plot_CourseSeaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars = sns.load_dataset('mpg').dropna()
cars.shape
# Out:
# (392, 9)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# # Univariate (1D)

# %%
sns.kdeplot(cars.horsepower);

# %%
sns.kdeplot(cars.horsepower, fill=True);

# %%
sns.kdeplot(cars.horsepower, bw_adjust=10);

# %%
sns.kdeplot(cars.horsepower, cumulative=True);

# %% [markdown]
# # Bivariate (2D)

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg);

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg, n_levels=20);

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg, fill=True);

# %%
sns.set_style('whitegrid')

sns.kdeplot(x=cars.horsepower, y=cars.mpg,
            fill=True,
            thresh=0.1
            );

# %%
sns.set_style('whitegrid')

sns.kdeplot(x=cars.horsepower, y=cars.mpg,
            fill=True,
            thresh=0.1,
            cbar=True
            );

# %%
cyl_4 = cars[cars.cylinders == 4]
cyl_8 = cars[cars.cylinders == 8]

plt.figure(figsize=(10, 6))

sns.kdeplot(x=cyl_4.horsepower, y=cyl_4.mpg, cmap='Blues', fill=True, thresh=0.1)
sns.kdeplot(x=cyl_8.horsepower, y=cyl_8.mpg, cmap='Reds', fill=True, thresh=0.1)

plt.xlabel('Horsepower', fontsize=14)
plt.ylabel('Miles per Gallon (MPG)', fontsize=14)

plt.annotate('4 Cylinders', (105, 32), color='blue', fontsize=16, fontweight='bold')
plt.annotate('8 Cylinders', (190, 18), color='red', fontsize=14, fontweight='bold');
